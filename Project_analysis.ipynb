# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Project_experiment1.csv", header=None, names=["Q-Learning"])

# %%
df.shape
# Out:
# (100000, 1)

# %%
df.rolling(1001, center=True).mean().plot(title='Learning Curve')
# Out:
# <Axes: title={'center': 'Learning Curve'}>

# %%
df[-10:].plot()
# Out:
# <Axes: >

# %%
df.plot(title='Learning Curves')
# Out:
# <Axes: title={'center': 'Learning Curves'}>

# %%
len(df[df['Q-Learning'] == 1]) / len(df)
# Out:
# 0.51596
