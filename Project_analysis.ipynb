# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("experiments\\1\\returns.csv", header=None, names=["Q-Learning", "eSARSA"])
df.rolling(1001, center=True).mean().plot()
# Out:
# <Axes: >

# %%
from pathlib import Path

# %%
fp = Path(f"experiments\\1\\agents\\q_learning\\0.csv")
df = pd.read_csv(fp, low_memory=True)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/parsers.pyx:1067, in pandas._libs.parsers.TextReader._convert_tokens()
# -> 1067 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:1177, in pandas._libs.parsers.TextReader._convert_with_dtype()
# -> 1177 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:1837, in pandas._libs.parsers._try_int64()
# -> 1837 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: Number is not int
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 fp = Path(f"experiments\\1\\agents\\q_learning\\0.csv")
# ----> 2 df = pd.read_csv(fp, low_memory=True)
# ...

# %%
fp2 = Path(f"experiments\\1\\agents\\eSARSA\\0.parquet")
df.to_parquet(fp2)
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[15], line 2
#       1 fp2 = Path(f"experiments\\1\\agents\\eSARSA\\0.parquet")
# ----> 2 df.to_parquet(fp2)
#
# File c:\Users\Diego\Desktop\rl_project\.venv\Lib\site-packages\pandas\core\frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3131         >>> content = f.read()
#    3132         """
#    3133         from pandas.io.parquet import to_parquet
#    3134
# -> 3135         return to_parquet(
#    3136             self,
#    3137             path,
#    3138             engine,
#
# File c:\Users\Diego\Desktop\rl_project\.venv\Lib\site-packages\pandas\io\parquet.py:486, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     484 if isinstance(partition_cols, str):
# ...
