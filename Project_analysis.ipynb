# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Project3_experiment1.csv", header=None, names=["Q-Learning"])

# %%
df.shape
# Out:
# (100000, 1)

# %%
df.rolling(1001, center=True).mean().plot(title='Learning Curves\nepsilon = 0.1')
# Out:
# <Axes: title={'center': 'Learning Curves\nepsilon = 0.1'}>

# %%
df[:1000].rolling(11, center=True).mean().plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df[:1000].rolling(11, center=True).plot()
#
# File c:\Users\Diego\Desktop\rl_project\.venv\Lib\site-packages\pandas\core\window\rolling.py:305, in BaseWindow.__getattr__(self, attr)
#     302 if attr in self.obj:
#     303     return self[attr]
# --> 305 raise AttributeError(
#     306     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     307 )
#
# AttributeError: 'Rolling' object has no attribute 'plot'

# %%
df.plot(title='Learning Curves\nepsilon = 0.1')
# Out:
# <Axes: title={'center': 'Learning Curves\nepsilon = 0.1'}>
